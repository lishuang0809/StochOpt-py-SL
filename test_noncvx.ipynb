# %%
from jax import grad
import jax.numpy as jnp

# %%
def Rosenbrock(X):  # Define a function
  y = jnp.sum(jnp.abs(100*(X[1:] - X[:-1]**2)**2 + (1 - X[:-1])**2))
  return y
grad_Rosenbrock = grad(Rosenbrock)
hess_Rosenbrock = grad(grad(Rosenbrock))

# %%
x = jnp.array([1.0,1.0,1.0])
print(x)
print(Rosenbrock(x))
# Out:
# [1. 1. 1.]
# 0.0

# %%
print(grad_Rosenbrock(x))
# Out:
# [0. 0. 0.]

# %%
import pybenchfunction as bench

# %%
# set the dimension of the input for the function
sphere = bench.function.Sphere(3)
# get results
X = jnp.array([1, 3, 0])
print(sphere(X))  # --> 10
# Out:
# 10

# %%
rosenbrock = bench.function.Rosenbrock(2)
#bench.plot_2d(sphere, n_space=100, ax=None)
bench.plot_3d(rosenbrock, n_space=100, ax=None)

# %%
d = 3
X = jnp.array([1 for _ in range(d)])
print(X)
# Out:
# [1 1 1]

# %%
X = jnp.array([1,2,3,4])
print(X)
# Out:
# [1 2 3 4]

# %%
print(X[1:])
# Out:
# [2 3 4]

# %%
print(X[:-1])
# Out:
# [1 2 3]

# %%
i = 2
print(X)
print(X[i])
print(X[i:])
print(X[:-i])
# Out:
# [1 2 3 4]
# 3
# [3 4]
# [1 2]

# %%
# Out:
# 3
